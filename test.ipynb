# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('azure.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.set_index('timestamp')

# %%
train_df = df.iloc[0:len(df)]
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = pd.DataFrame(scaler.fit_transform(train_df), columns=df.columns)

# %%
def train_generator(dataset, n_lags=1):
    data_X, data_Y = [], []
    for i in range(len(dataset) - n_lags - 1):
        print(i)
        a = dataset.iloc[i:(i+n_lags)].to_numpy()
        data_X.append(a)
        data_Y.append(dataset.iloc[i + n_lags].to_numpy())
        break
    return np.array(data_X), np.array(data_Y)

# %%
ds = [i for i in range(0, 1000)]

# %%
bla = train_generator(train_df, 50)
len(bla[0][0])
# Out:
# 0
# array([[[ 715146.536821  , 2223302.43296698, 1229569.37124299],
#         [ 700473.84032401, 2212393.24571498, 1211321.70868102],
#         [ 705953.56585002, 2213056.745169  , 1206634.91394498],
#         [ 688383.073221  , 2187572.23935801, 1190368.50685501],
#         [ 688276.55103299, 2183684.48590098, 1180991.68770601],
#         [ 691089.138618  , 2284281.56840802, 1220288.95630701],
#         [ 683834.76771701, 2200116.40977098, 1192507.88673801],
#         [ 671049.32920299, 2173881.26103097, 1164390.148936  ],
#         [ 668678.42012901, 2171678.92285198, 1163261.86101202],
#         [ 669317.424569  , 2182964.84308901, 1164324.219565  ],
#         [ 666220.053861  , 2179623.296251  , 1166436.30137001],
#         [ 684861.27437099, 2200703.217208  , 1190592.42982899],
#         [ 668646.728537  , 2176372.209397  , 1171241.89756101],
#         [ 664510.65760201, 2148640.059295  , 1148830.630059  ],
#         [ 661465.67773799, 2138898.03049695, 1141471.597877  ],
# ...
